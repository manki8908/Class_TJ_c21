# %%
'''
클래스(class)?
 - 함수의 모임
 - 역할 : 다수의 함수와 공유 자료를 묶어서 객체 생성
 - 구성 : 멤버(member) + 생성자 
 - 멤버 : 변수(자료) + 함수(기능) 
 - 유형 : 사용자 정의 클래스, 내장 클래스(python)
 - 형식)
 class 클래스 :
     멤버(member) : 변수, 함수 
     생성자 : 객체 생성 
'''

# (1) 함수와 클래스

# 클래스 정의
class calc_class :
    # class 변수 선언
    x = y = 0
    count = 0
    
    # 생성자 : 객체 생성 + [멤버변수 동적할당] 
    def __init__(self, a):
        print('~~객체 생성~~')
        self.x = a # 10
        #self.y = b # 20
        calc_class.count += 1
    
    # 멤버 함수(기능)
    def plus(self): # self : 멤버(변수+함수) 참조 객체 
        p = self.x + self.y
        '''
        p : 지역변수 
        self.x, self.y : 전역변수  
        '''
        return p 
    
    def minus(self):
        m = self.x - self.y
        return m
    
      
# class(1) -> object(n) 생성 
#obj1 = calc_class(10, 20) # 생성자 -> 객체1  
obj2 = calc_class(10) # 생성자 -> 객체1  

# # object.member()  
# print('plus = ', obj1.plus()) # plus =  30
# print('minus =', obj1.minus()) # minus = -10

# obj2 = calc_class(100, 50) # 생성자 -> 객체2
# print('plus = ', obj2.plus()) # plus =  150
# print('minus =', obj2.minus()) # minus = 50

# print(id(obj1), id(obj2)) # 9498096 9498000

#obj1.x = 100
obj2.y = 200
print(obj2.y)
#print(calc_class.y)
# Out:
# ~~객체 생성~~
# 200

# %%
# 예제-02
# 클래스 정의
class calc_class :
    # 변수 선언
    x = y = 0
    # 생성자 : 객체 생성 + [멤버변수 초기화] 
    def __init__(self, a, b):
        print('~~객체 생성~~')
        self.x = a # 10
        self.y = b # 20
    # 멤버 함수(기능)
    def plus(self): # self : 멤버(변수+함수) 참조 객체 
        p = self.x + self.y
        '''
        p : 지역변수 
        self.x, self.y : 전역변수  
        '''
        return p 
    def minus(self):
        m = self.x - self.y
        return m
# class(1) -> object(n) 생성 
obj1 = calc_class(10, 20) # 생성자 -> 객체1  
# object.member()  
print('plus = ', obj1.plus()) # plus =  30
print('minus =', obj1.minus()) # minus = -10



obj3 = calc_class(70, 90) # 생성자 -> 객체2
print('plus = ', obj3.plus()) # plus =  30
print('minus =', obj3.minus()) # minus = -10
# Out:
# ~~객체 생성~~
# plus =  30
# minus = -10
# ~~객체 생성~~
# plus =  160
# minus = -20

# %%
# 예제-02
# 클래스 정의
class calc_class :
    # 변수 선언
    x = y = 0
    # 생성자 : 객체 생성 + [멤버변수 초기화] 
    def __init__(self, a, b):
        print('~~객체 생성~~')
        self.x = a # 10
        self.y = b # 20
    # 멤버 함수(기능)
    def plus(self): # self : 멤버(변수+함수) 참조 객체 
        p = self.x + self.y
        '''
        p : 지역변수 
        self.x, self.y : 전역변수  
        '''
        return p 
    def minus(self):
        m = self.x - self.y
        return m
    
# class(1) -> object(n) 생성 
obj1 = calc_class(10, 20) # 생성자 -> 객체1  
# object.member()  
print('plus = ', obj1.plus()) # plus =  30
print('minus =', obj1.minus()) # minus = -10


obj3 = calc_class(70, 90) # 생성자 -> 객체2
print('plus = ', obj3.plus()) # plus =  30
print('minus =', obj3.minus()) # minus = -10


# ------------ 065일차-실습-0-3
# 가
obj2 = calc_class(0, 0) # 생성자 -> 객체2
print('plus = ', obj2.plus()) # plus =  30
print('minus =', obj2.minus()) # minus = -10

# 나 
obj3.x = 200
obj3.y = 50

# 다
print('plus = ', obj3.plus()) # plus =  30
print('minus =', obj3.minus()) # minus = -10
# Out:
# ~~객체 생성~~
# plus =  30
# minus = -10
# ~~객체 생성~~
# plus =  160
# minus = -20
# ~~객체 생성~~
# plus =  0
# minus = 0
# plus =  250
# minus = 150

# %%
# 065일차-실습-0-3-해답
# 클래스 정의
class calc_class :
    # 변수 선언
    #x = y = 0
    # 생성자 : 객체 생성 + [멤버변수 초기화]
    def __init__(self, a, b):
        print('\n~~객체 생성~~')
        self.x = a # 10
        self.y = b # 20
    # 멤버 함수(기능)
    def plus(self): # self : 멤버(변수+함수) 참조 객체
        p = self.x + self.y
        '''
        p : 지역변수
        self.x, self.y : 전역변수  
        '''
        return p
    def minus(self):
        m = self.x - self.y
        return m
# class(1) -> object(n) 생성
obj1 = calc_class(10, 20) # 생성자 -> 객체1  
#
print('obj1 plus = ', obj1.plus()) # plus =  30
print('obj1 minus =', obj1.minus()) # minus = -10
#
obj03 = calc_class(70,90)
print('obj03 plus_1 = ', obj03.plus())
print('obj03 minus_1 =', obj03.minus())
#
obj2 = calc_class(0,0)  # 코딩조건 가. 
                        # 객체(object)를 만들고 객체의 주소를 obj2에 할당함
                        # 이 때 인수로 0,0 을 할당함
#
obj03.x = 200            # 코딩조건 나. obj03객체의 맴버변수 x에 200을 할당함 
obj03.y = 50             # 코딩조건 나. obj03객체의 맴버변수 y에 50을 할당함
#
print('obj03 plus_2 = ', obj03.plus())  # 코딩조건 다. obj03객체의 맴버메서드 실행 
print('obj03 minus_2 =', obj03.minus()) # 코딩조건 다. obj03객체의 맴버메서드 실행 
#
print('obj2 plus_1= ', obj2.plus())  #  obj2객체의 맴버메서드 실행 
print('obj2 minus_1=', obj2.minus()) #  obj2객체의 맴버메서드 실행 
#
obj2.x = 999            # 코딩조건 나. obj2객체의 맴버변수 x에 999을 할당함 
obj2.y = 888            # 코딩조건 나. obj2객체의 맴버변수 y에 888을 할당함
#
print('obj2 plus_2= ', obj2.plus())  #  obj2객체의 맴버메서드 실행 
print('obj2 minus_2=', obj2.minus()) #  obj2객체의 맴버메서드 실행 
#
print('obj03 plus_3 = ', obj03.plus())  # 코딩조건 다. obj03객체의 맴버메서드 실행 
print('obj03 minus_3 =', obj03.minus()) # 코딩조건 다. obj03객체의 맴버메서드 실행
# Out:
# ~~객체 생성~~
# obj1 plus =  30
# obj1 minus = -10
#
# ~~객체 생성~~
# obj03 plus_1 =  160
# obj03 minus_1 = -20
#
# ~~객체 생성~~
# obj03 plus_2 =  250
# obj03 minus_2 = 150
# obj2 plus_1=  0
# obj2 minus_1= 0
# obj2 plus_2=  1887
# obj2 minus_2= 111
# obj03 plus_3 =  250
# obj03 minus_3 = 150
